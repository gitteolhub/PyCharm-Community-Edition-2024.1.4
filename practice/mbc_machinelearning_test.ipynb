# %%
# !pip install wordcloud konlpy
# Out:
# ...
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt
from konlpy.tag import Okt
from collections import Counter
from wordcloud import WordCloud
import matplotlib.font_manager as fm

# %%
with open('D:/student/LHT/추천시스템.txt', 'r', encoding='utf-8') as file:
    text = file.read()

# %%
okt = Okt()

nouns = okt.nouns(text)

word_count = Counter(nouns)

# %%
font_path = 'C:\Windows\Fonts\malgun.ttf'
font_name = fm.FontProperties(fname=font_path).get_name()
plt.rc('font', family=font_name)

# %%
top_words = word_count.most_common(20)

plt.figure(figsize=(12, 5))
plt.bar([word for word, count in top_words], [count for word, count in top_words])
plt.xlabel('키워드')
plt.ylabel('빈도수')
plt.title('히스토그램')
plt.xticks(rotation=45)

plt.grid(which='both', axis='both', linestyle='-', linewidth=0.5)
plt.xticks(range(0, len(top_words) + 1, 1))
plt.yticks(range(0, max([count for word, count in top_words]) + 1, 10))

plt.show()

# %%
wordcloud = WordCloud(font_path=font_path, background_color='ivory', width=800, height=600).generate_from_frequencies(word_count)

plt.figure(figsize=(8, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('워드클라우드')
plt.show()
